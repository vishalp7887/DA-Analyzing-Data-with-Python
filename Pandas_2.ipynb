# %%
import pandas as pd

# %%
d1 = pd.read_csv('covid.csv')
d1
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     NaN    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                        Goa     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
d1.head()
# Out:
#                  state  confirmed  active  passive   deaths       dose1  \
# 0  Andaman and Nicobar      10742     1.0    10612    129.0    313284.0
# 1       Andhra Pradesh    2339067     3.0  2324331  14733.0  40643161.0
# 2    Arunachal Pradesh      66890     NaN    66594    296.0    860442.0
# 3                Assam     746100     0.0   738065   8035.0  22549957.0
# 4                Bihar     851379    15.0   839062  12302.0  62944633.0
#
#       dose2       dose3  precaution_dose  total_doses   population
# 0    320383    236936.0          53427.0       991263     426251.0
# 1  43549055  11703273.0        6579565.0    110556756   52883163.0
# 2    747177         NaN          58618.0      1911760    1528296.0
# 3  20561790   2082670.0        1259853.0     50284713   34586234.0
# 4  59144387  11983504.0        3868082.0    157197041  119461013.0

# %%
d1.tail()
# Out:
#             state  confirmed  active  passive   deaths        dose1  \
# 31      Telengana     841324    71.0   837142   4111.0   29607672.0
# 32        Tripura     108034     0.0   107094    940.0    2658852.0
# 33  Uttar Pradesh    2128103    46.0  2104424  23633.0  154058287.0
# 34    Uttarakhand     449379    28.0   441600   7751.0    8180312.0
# 35    West Bengal    2118606    58.0  2097016  21532.0   67300236.0
#
#         dose2       dose3  precaution_dose  total_doses   population
# 31   29053708  10525975.0        2702159.0     77201709   38472769.0
# 32    2328613    271434.0         204733.0      5916312    4057847.0
# 33  147716010  35623544.0        9240735.0    390639497  228959599.0
# 34    7940592   1346150.0         867047.0     20051714   11090425.0
# 35   61593452  10257324.0        5491943.0    155962840   97694960.0

# %%
d1.columns
# Out:
# Index(['state', 'confirmed', 'active', 'passive', 'deaths', 'dose1', 'dose2',
#        'dose3', 'precaution_dose', 'total_doses', 'population'],
#       dtype='object')

# %%
d1.loc[0]
# Out:
# state              Andaman and Nicobar
# confirmed                        10742
# active                             1.0
# passive                          10612
# deaths                           129.0
# dose1                         313284.0
# dose2                           320383
# dose3                         236936.0
# precaution_dose                53427.0
# total_doses                     991263
# population                    426251.0
# Name: 0, dtype: object

# %%
d1.loc[5]
# Out:
# state              Chandigarh
# confirmed               99348
# active                    6.0
# passive                 98161
# deaths                    NaN
# dose1               1089254.0
# dose2                  917701
# dose3                 48480.0
# precaution_dose       63046.0
# total_doses           2282281
# population          1182104.0
# Name: 5, dtype: object

# %%
d1.loc[[5,10,20]]
# Out:
#           state  confirmed  active  passive    deaths       dose1     dose2  \
# 5    Chandigarh      99348     6.0    98161       NaN   1089254.0    917701
# 10      Gujarat    1277557    41.0  1266473   11043.0  49314588.0  49428283
# 20  Maharashtra    8136588   164.0  7988008  148416.0  84644083.0  71593498
#
#          dose3  precaution_dose  total_doses   population
# 5      48480.0          63046.0      2282281    1182104.0
# 10  13459618.0        5938121.0    127793995   63907200.0
# 20   5022623.0        4450343.0    177678317  120837347.0

# %%
d1[4:9]
# Out:
#                                       state  confirmed  active  passive  \
# 4                                     Bihar     851379    15.0   839062
# 5                                Chandigarh      99348     6.0    98161
# 6                              Chhattisgarh    1177749     6.0  1163597
# 7  Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                     Delhi    2007188    35.0  1980632
#
#     deaths       dose1     dose2       dose3  precaution_dose  total_doses  \
# 4  12302.0  62944633.0  59144387  11983504.0        3868082.0    157197041
# 5      NaN   1089254.0    917701     48480.0          63046.0      2282281
# 6  14146.0         NaN  18534989   5737679.0        1804891.0     49148991
# 7      4.0    730746.0    594929    136967.0              NaN      1578492
# 8  26521.0         NaN  14348835   2312803.0        1053393.0     37366540
#
#     population
# 4  119461013.0
# 5    1182104.0
# 6   28566990.0
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            36 non-null     object
#  1   confirmed        36 non-null     int64
#  2   active           34 non-null     float64
#  3   passive          36 non-null     int64
#  4   deaths           35 non-null     float64
#  5   dose1            34 non-null     float64
#  6   dose2            36 non-null     int64
#  7   dose3            34 non-null     float64
#  8   precaution_dose  35 non-null     float64
#  9   total_doses      36 non-null     int64
#  10  population       35 non-null     float64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 3.2+ KB

# %%
pd.options.display.max_rows = 20
d1
# Out:
#                   state  confirmed  active  passive   deaths        dose1  \
# 0   Andaman and Nicobar      10742     1.0    10612    129.0     313284.0
# 1        Andhra Pradesh    2339067     3.0  2324331  14733.0   40643161.0
# 2     Arunachal Pradesh      66890     NaN    66594    296.0     860442.0
# 3                 Assam     746100     0.0   738065   8035.0   22549957.0
# 4                 Bihar     851379    15.0   839062  12302.0   62944633.0
# ..                  ...        ...     ...      ...      ...          ...
# 31            Telengana     841324    71.0   837142   4111.0   29607672.0
# 32              Tripura     108034     0.0   107094    940.0    2658852.0
# 33        Uttar Pradesh    2128103    46.0  2104424  23633.0  154058287.0
# 34          Uttarakhand     449379    28.0   441600   7751.0    8180312.0
# 35          West Bengal    2118606    58.0  2097016  21532.0   67300236.0
#
#         dose2       dose3  precaution_dose  total_doses   population
# ...

# %%
d1.isnull()
# Out:
#     state  confirmed  active  passive  deaths  dose1  dose2  dose3  \
# 0   False      False   False    False   False  False  False  False
# 1   False      False   False    False   False  False  False  False
# 2   False      False    True    False   False  False  False   True
# 3   False      False   False    False   False  False  False  False
# 4   False      False   False    False   False  False  False  False
# ..    ...        ...     ...      ...     ...    ...    ...    ...
# 31  False      False   False    False   False  False  False  False
# 32  False      False   False    False   False  False  False  False
# 33  False      False   False    False   False  False  False  False
# 34  False      False   False    False   False  False  False  False
# 35  False      False   False    False   False  False  False  False
#
#     precaution_dose  total_doses  population
# 0             False        False       False
# 1             False        False       False
# ...

# %%
d1.isnull().sum()
# Out:
# state              0
# confirmed          0
# active             2
# passive            0
# deaths             1
# dose1              2
# dose2              0
# dose3              2
# precaution_dose    1
# total_doses        0
# population         1
# dtype: int64

# %%
d1.isnull().sum().sum()
# Out:
# 9

# %%
d1['active'].fillna(50, inplace = True)
d1
# Out:
#                   state  confirmed  active  passive   deaths        dose1  \
# 0   Andaman and Nicobar      10742     1.0    10612    129.0     313284.0
# 1        Andhra Pradesh    2339067     3.0  2324331  14733.0   40643161.0
# 2     Arunachal Pradesh      66890    50.0    66594    296.0     860442.0
# 3                 Assam     746100     0.0   738065   8035.0   22549957.0
# 4                 Bihar     851379    15.0   839062  12302.0   62944633.0
# ..                  ...        ...     ...      ...      ...          ...
# 31            Telengana     841324    71.0   837142   4111.0   29607672.0
# 32              Tripura     108034     0.0   107094    940.0    2658852.0
# 33        Uttar Pradesh    2128103    46.0  2104424  23633.0  154058287.0
# 34          Uttarakhand     449379    28.0   441600   7751.0    8180312.0
# 35          West Bengal    2118606    58.0  2097016  21532.0   67300236.0
#
#         dose2       dose3  precaution_dose  total_doses   population
# ...

# %%
d1.dropna()
# Out:
#                   state  confirmed  active  passive   deaths        dose1  \
# 0   Andaman and Nicobar      10742     1.0    10612    129.0     313284.0
# 1        Andhra Pradesh    2339067     3.0  2324331  14733.0   40643161.0
# 3                 Assam     746100     0.0   738065   8035.0   22549957.0
# 4                 Bihar     851379    15.0   839062  12302.0   62944633.0
# 9                   Goa     259079    26.0   255040   4013.0    1354828.0
# ..                  ...        ...     ...      ...      ...          ...
# 31            Telengana     841324    71.0   837142   4111.0   29607672.0
# 32              Tripura     108034     0.0   107094    940.0    2658852.0
# 33        Uttar Pradesh    2128103    46.0  2104424  23633.0  154058287.0
# 34          Uttarakhand     449379    28.0   441600   7751.0    8180312.0
# 35          West Bengal    2118606    58.0  2097016  21532.0   67300236.0
#
#         dose2       dose3  precaution_dose  total_doses   population
# ...

# %%
d2 = pd.read_csv('D:\\vishal data\\csv file\\audi.csv')
d2
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
d2.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
print(d2.to_string())
# Out:
#       model  year   price transmission  mileage fuelType  tax    mpg  engineSize
# 0        A1  2017   12500       Manual    15735   Petrol  150   55.4         1.4
# 1        A6  2016   16500    Automatic    36203   Diesel   20   64.2         2.0
# 2        A1  2016   11000       Manual    29946   Petrol   30   55.4         1.4
# 3        A4  2017   16800    Automatic    25952   Diesel  145   67.3         2.0
# 4        A3  2019   17300       Manual     1998   Petrol  145   49.6         1.0
# 5        A1  2016   13900    Automatic    32260   Petrol   30   58.9         1.4
# 6        A6  2016   13250    Automatic    76788   Diesel   30   61.4         2.0
# 7        A4  2016   11750       Manual    75185   Diesel   20   70.6         2.0
# 8        A3  2015   10200       Manual    46112   Petrol   20   60.1         1.4
# 9        A1  2016   12000       Manual    22451   Petrol   30   55.4         1.4
# 10       A3  2017   16100       Manual    28955   Petrol  145   58.9         1.4
# ...

# %%
d2.isnull()
# Out:
#        model   year  price  transmission  mileage  fuelType    tax    mpg  \
# 0      False  False  False         False    False     False  False  False
# 1      False  False  False         False    False     False  False  False
# 2      False  False  False         False    False     False  False  False
# 3      False  False  False         False    False     False  False  False
# 4      False  False  False         False    False     False  False  False
# ...      ...    ...    ...           ...      ...       ...    ...    ...
# 10663  False  False  False         False    False     False  False  False
# 10664  False  False  False         False    False     False  False  False
# 10665  False  False  False         False    False     False  False  False
# 10666  False  False  False         False    False     False  False  False
# 10667  False  False  False         False    False     False  False  False
#
#        engineSize
# 0           False
# 1           False
# 2           False
# ...

# %%
d2.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
d2.isnull().sum().sum()
# Out:
# 0
