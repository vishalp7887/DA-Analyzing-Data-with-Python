# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.5.2'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
arr1 = np.array([2, 6])
arr2 = np.array([1,4])

arr3 = plt.plot(arr1, arr2)

# %%
arr1 = np.array([2, 6])
arr2 = np.array([1,4])

arr3 = plt.plot(arr1, arr2, 'o')

# %%
covid = pd.read_csv('D:\\vishal data\\csv file\\covid.csv')

# %%
covid.head()
# Out:
#    No                state  confirmed  active  passive  deaths     dose1  \
# 0   1  Andaman and Nicobar      10742      74    10612      67    313284
# 1   2       Andhra Pradesh    2339067      88  2324331      68  40643161
# 2   3    Arunachal Pradesh      66890      53    66594      77    860442
# 3   4                Assam     746100      57   738065      91  22549957
# 4   5                Bihar     851379      96   839062      85  62944633
#
#       dose2     dose3  precaution_dose  total_doses  population
# 0    320383    236936            53427       991263      426251
# 1  43549055  11703273          6579565    110556756    52883163
# 2    747177     72403            58618      1911760     1528296
# 3  20561790   2082670          1259853     50284713    34586234
# 4  59144387  11983504          3868082    157197041   119461013

# %%
arr4 = plt.plot(covid['No'], covid['active'], 'o', )

# %%
arr5 = plt.plot(covid['No'], covid['active'])

# %%
seller = pd.read_csv('D:\\vishal data\\csv file\\seller.csv')

# %%
seller
# Out:
#    SELLER_ID COUNTRY  YEARR  SALES  mobile_no
# 0          1      UK   2022  50000      12345
# 1          2     AUS   2020  25000      23456
# 2          6  CANADA   2022  60000      67890
# 3          4   CHINA   2020  30000      45678
# 4          5      uk   2021  40000      56789
# 5          8     NZL   2019  30000      89000
# 6          7     IND   2020  60000      78900
# 7          3     NZL   2020  40000      34567
# 8          9     AUS   2022  60000      90000

# %%
seller1 = plt.plot(seller['COUNTRY'], seller['SALES'], '*')

# %%
seller2 = plt.plot(seller['YEARR'], seller['SALES'], '*')

# %%
seller3 = plt.plot(seller['SALES'], 'o')

# %%
seller3 = plt.plot(seller['SALES'], marker = '+')

# %%
seller3 = plt.plot(seller['SALES'], 'o:r')

# %%
seller3 = plt.plot(seller['SALES'], 'o--')

# %%
seller3 = plt.plot(seller['SALES'], 'o:')

# %%
seller3 = plt.plot(seller['SALES'], 'o-.')

# %%
seller3 = plt.plot(seller['SALES'], 'g')

# %%
seller4 = plt.plot(seller['SALES'], 'o', ms = '15')

# %%
seller5 = plt.plot(seller['SALES'], 'o', ms = '15', mec = 'r')

# %%
seller5 = plt.plot(seller['SALES'], 'o', ms = '15', mfc = 'r')

# %%
seller6 = plt.plot(seller['SALES'], 'o', ms = '15', mfc = 'r', mec = 'r')
