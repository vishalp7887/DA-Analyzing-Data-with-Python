# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\vishal data\\csv file\\supermarket_sales.csv')
df
# Out:
#       Invoice_ID STORE Customer type  Gender            Product_line  \
# 0    750-67-8428     B        Member  Female       Health and beauty
# 1    226-31-3081     B        Normal  Female  Electronic accessories
# 2    631-41-3108     C        Normal    Male      Home and lifestyle
# 3    123-19-1176     D        Member    Male       Health and beauty
# 4    373-73-7910     B        Normal    Male       Sports and travel
# ..           ...   ...           ...     ...                     ...
# 295  211-05-0490     E        Member  Female  Electronic accessories
# 296  727-75-6477     D        Normal    Male  Electronic accessories
# 297  744-02-5987     C        Member    Male      Home and lifestyle
# 298  307-83-9164     A        Member    Male      Home and lifestyle
# 299  779-06-0012     D        Member  Female      Home and lifestyle
#
#      Unit_price  Quantity   Tax _5     Total  Rating      P_date      EEID
# ...

# %%
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
