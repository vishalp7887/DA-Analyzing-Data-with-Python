# %%
import pandas as pd

# %%
d = {
    'name' : ['vishal', 'vaibhavi', 'soham', 'srushti'],
    'roll_no' : [12,34,56,78],
}

# %%
print(d)
print(type(d))
# Out:
# {'name': ['vishal', 'vaibhavi', 'soham', 'srushti'], 'roll_no': [12, 34, 56, 78]}
# <class 'dict'>

# %%
data = pd.DataFrame(d)
print(data)
# Out:
#        name  roll_no
# 0    vishal       12
# 1  vaibhavi       34
# 2     soham       56
# 3   srushti       78

# %%
d1 = [1,2,5,3,5,2,4]

# %%
print(d1)
print(type(d1))
# Out:
# [1, 2, 5, 3, 5, 2, 4]
# <class 'list'>

# %%
s = pd.Series(d1)
print(s)
# Out:
# 0    1
# 1    2
# 2    5
# 3    3
# 4    5
# 5    2
# 6    4
# dtype: int64

# %%
df = pd.read_csv('supermart.csv')
print(df)
# Out:
#    ORDER_ID CUSTOMER_NAME       CATEGORY       CITY  ORDER_DATE  PRICE  \
# 0       101         name1           food  ahmedabad  12-08-2004    899
# 1       102         name2            oil     baroda  10-11-2021    799
# 2       103         name3          cakes  ahmedabad  02-01-2022   1399
# 3       104         name4         fruits       pune  01-12-2021   1299
# 4       105         name5     chocolates      surat  15-12-2021    999
# 5       106         name6           rice  ahmedabad  20-11-2021   1799
# 6       107         name7          cakes     mumbai  01-12-2021    899
# 7       108         name8        cookies  bangalore  03-02-2022   2999
# 8       109         name9  health drinks       pune  19-02-2021   1999
# 9       110        name10        noodles     mumbai  09-04-2022    599
#
#          STATE
# 0       gujrat
# 1       gujrat
# 2       gujrat
# 3  maharashtra
# 4       gujrat
# 5       gujrat
# 6  maharashtra
# 7    karnataka
# 8  maharashtra
# 9  maharashtra

# %%
df = pd.read_csv('supermart.csv')
print(df.to_string())
# Out:
#    ORDER_ID CUSTOMER_NAME       CATEGORY       CITY  ORDER_DATE  PRICE        STATE
# 0       101         name1           food  ahmedabad  12-08-2004    899       gujrat
# 1       102         name2            oil     baroda  10-11-2021    799       gujrat
# 2       103         name3          cakes  ahmedabad  02-01-2022   1399       gujrat
# 3       104         name4         fruits       pune  01-12-2021   1299  maharashtra
# 4       105         name5     chocolates      surat  15-12-2021    999       gujrat
# 5       106         name6           rice  ahmedabad  20-11-2021   1799       gujrat
# 6       107         name7          cakes     mumbai  01-12-2021    899  maharashtra
# 7       108         name8        cookies  bangalore  03-02-2022   2999    karnataka
# 8       109         name9  health drinks       pune  19-02-2021   1999  maharashtra
# 9       110        name10        noodles     mumbai  09-04-2022    599  maharashtra

# %%
df = pd.read_csv('Pivot_Data.csv')
print(df)
# Out:
#       Creating a Pivot Table          Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0                        NaN                 NaN            NaN        NaN
# 1                       Year                Type  Product group   Producer
# 2                       2011  Convenience stores           Meat        J&F
# 3                       2011  Convenience stores           Meat        J&F
# 4                       2011  Convenience stores           Meat        J&F
# ...                      ...                 ...            ...        ...
# 15115                   2013        Supermarkets     Vegetables    Monzuro
# 15116                   2013        Supermarkets     Vegetables    Monzuro
# 15117                   2013        Supermarkets     Vegetables    Monzuro
# 15118                   2013        Supermarkets     Vegetables    Monzuro
# 15119                   2013        Supermarkets     Vegetables    Monzuro
#
#         Unnamed: 4 Unnamed: 5     Unnamed: 6      Unnamed: 7
# ...

# %%
df = pd.read_csv('Pivot_Data.csv')
print(df.to_string())
# Out:
#       Creating a Pivot Table          Unnamed: 1         Unnamed: 2             Unnamed: 3    Unnamed: 4 Unnamed: 5     Unnamed: 6      Unnamed: 7
# 0                        NaN                 NaN                NaN                    NaN           NaN        NaN            NaN             NaN
# 1                       Year                Type      Product group               Producer          Code     Volume  Cost per unit  Price per unit
# 2                       2011  Convenience stores               Meat                    J&F    |13/12/38|        420            6.0             8.4
# 3                       2011  Convenience stores               Meat                    J&F    |13/13/98|        480            6.1             7.4
# 4                       2011  Convenience stores               Meat                    J&F    |13/13/99|        528            5.4             7.6
# ...

# %%
df = pd.read_csv('supermart.csv')
print(df.to_string())
# Out:
#    ORDER_ID CUSTOMER_NAME       CATEGORY       CITY  ORDER_DATE  PRICE        STATE
# 0       101         name1           food  ahmedabad  12-08-2004    899       gujrat
# 1       102         name2            oil     baroda  10-11-2021    799       gujrat
# 2       103         name3          cakes  ahmedabad  02-01-2022   1399       gujrat
# 3       104         name4         fruits       pune  01-12-2021   1299  maharashtra
# 4       105         name5     chocolates      surat  15-12-2021    999       gujrat
# 5       106         name6           rice  ahmedabad  20-11-2021   1799       gujrat
# 6       107         name7          cakes     mumbai  01-12-2021    899  maharashtra
# 7       108         name8        cookies  bangalore  03-02-2022   2999    karnataka
# 8       109         name9  health drinks       pune  19-02-2021   1999  maharashtra
# 9       110        name10        noodles     mumbai  09-04-2022    599  maharashtra

# %%
d1 = pd.read_csv('EMPLOYEE.CSV')
print(d1)
# Out:
#     ID    EEID         FULL_NAME  AGE Annual_Salary  REVIEW SRORE_ID
# 0    1  101001       Emily Davis   55      1,41,604       3        A
# 1    2  101002     Theodore Dinh   59        99,975       5        A
# 2    3  101003      Luna Sanders   50      1,63,099       5        A
# 3    4  101004   Penelope Jordan   26        84,913       4        A
# 4    5  101005         Austin Vo   55        95,409       5        A
# 5    6  101006      Joshua Gupta   57        50,994       4        A
# 6    7  101007       Ruby Barnes   27      1,19,746       2        A
# 7    8  101008       Luke Martin   25        41,336       1        A
# 8    9  101009     Easton Bailey   29      1,13,527       2        A
# 9   10  101010   Madeline Walker   34        77,203       4        A
# 10  11  101011      Savannah Ali   36      1,57,333       3        B
# 11  12  101012     Camila Rogers   27      1,09,851       1        B
# 12  13  101013         Eli Jones   59      1,05,086       3        B
# ...

# %%
d2 = pd.read_csv('EMPLOYEE.csv')
print(d2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             50 non-null     int64
#  1   EEID           50 non-null     int64
#  2   FULL_NAME      50 non-null     object
#  3   AGE            50 non-null     int64
#  4   Annual_Salary  50 non-null     object
#  5   REVIEW         50 non-null     int64
#  6   SRORE_ID       50 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 2.9+ KB
# None

# %%
# return in first 5 rows
print(d2.head())
# Out:
#    ID    EEID        FULL_NAME  AGE Annual_Salary  REVIEW SRORE_ID
# 0   1  101001      Emily Davis   55      1,41,604       3        A
# 1   2  101002    Theodore Dinh   59        99,975       5        A
# 2   3  101003     Luna Sanders   50      1,63,099       5        A
# 3   4  101004  Penelope Jordan   26        84,913       4        A
# 4   5  101005        Austin Vo   55        95,409       5        A

# %%
# return in last 5 rows
print(d2.tail())
# Out:
#     ID    EEID       FULL_NAME  AGE Annual_Salary  REVIEW SRORE_ID
# 45  46  101046  Gabriel Holmes   40        92,952       5        E
# 46  47  101047     Wyatt Rojas   32        79,921       5        E
# 47  48  101048     Eva Coleman   37      1,67,199       2        E
# 48  49  101049   Dominic Clark   52        71,476       2        E
# 49  50  101050  Lucy Alexander   45      1,89,420       5        E

# %%
print(d2.head(3))
# Out:
#    ID    EEID      FULL_NAME  AGE Annual_Salary  REVIEW SRORE_ID
# 0   1  101001    Emily Davis   55      1,41,604       3        A
# 1   2  101002  Theodore Dinh   59        99,975       5        A
# 2   3  101003   Luna Sanders   50      1,63,099       5        A

# %%
print(d2.tail(2))
# Out:
#     ID    EEID       FULL_NAME  AGE Annual_Salary  REVIEW SRORE_ID
# 48  49  101049   Dominic Clark   52        71,476       2        E
# 49  50  101050  Lucy Alexander   45      1,89,420       5        E

# %%
import pandas as pd

# %%
d1 = pd.read_csv('covid.csv')

# %%
d1
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     NaN    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                        Goa     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
d1[['state', 'dose1']]
# Out:
#                                        state        dose1
# 0                        Andaman and Nicobar     313284.0
# 1                             Andhra Pradesh   40643161.0
# 2                          Arunachal Pradesh     860442.0
# 3                                      Assam   22549957.0
# 4                                      Bihar   62944633.0
# 5                                 Chandigarh    1089254.0
# 6                               Chhattisgarh          NaN
# 7   Dadra and Nagar Haveli and Daman and Diu     730746.0
# 8                                      Delhi          NaN
# 9                                        Goa    1354828.0
# 10                                   Gujarat   49314588.0
# 11                                   Haryana   21955717.0
# 12                          Himachal Pradesh    6041658.0
# 13                         Jammu and Kashmir    9941757.0
# 14                                 Jharkhand   21300448.0
# ...
