# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Covid.csv')
df1.head()
# Out:
#                  state  confirmed  active  passive   deaths       dose1  \
# 0  Andaman and Nicobar      10742     1.0    10612    129.0    313284.0
# 1       Andhra Pradesh    2339067     3.0  2324331  14733.0  40643161.0
# 2    Arunachal Pradesh      66890     NaN    66594    296.0    860442.0
# 3                Assam     746100     0.0   738065   8035.0  22549957.0
# 4                Bihar     851379    15.0   839062  12302.0  62944633.0
#
#       dose2       dose3  precaution_dose  total_doses   population
# 0    320383    236936.0          53427.0       991263     426251.0
# 1  43549055  11703273.0        6579565.0    110556756   52883163.0
# 2    747177         NaN          58618.0      1911760    1528296.0
# 3  20561790   2082670.0        1259853.0     50284713   34586234.0
# 4  59144387  11983504.0        3868082.0    157197041  119461013.0

# %%
df2 = pd.read_csv('Covid.csv', na_values = 'Goa')
df2
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     NaN    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                        NaN     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
df4 = pd.read_csv('Covid.csv', na_values = ['Tripura', 0.0])
df4
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     NaN    66594
# 3                                      Assam     746100     NaN   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     NaN    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                        Goa     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
df2.fillna(method = 'bfill')
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     0.0    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                    Gujarat     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
df2.fillna(method = 'ffill')
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     3.0    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      Bihar     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                      Delhi     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
df2.fillna(method = 'bfill', axis = 1)
# Out:
#                                        state confirmed  active   passive  \
# 0                        Andaman and Nicobar     10742     1.0     10612
# 1                             Andhra Pradesh   2339067     3.0   2324331
# 2                          Arunachal Pradesh     66890   66594     66594
# 3                                      Assam    746100     0.0    738065
# 4                                      Bihar    851379    15.0    839062
# 5                                 Chandigarh     99348     6.0     98161
# 6                               Chhattisgarh   1177749     6.0   1163597
# 7   Dadra and Nagar Haveli and Daman and Diu     11591     0.0     11587
# 8                                      Delhi   2007188    35.0   1980632
# 9                                   259079.0  259079.0    26.0  255040.0
# 10                                   Gujarat   1277557    41.0   1266473
# 11                                   Haryana   1056602    43.0   1045845
# ...

# %%
df2.fillna(method = 'ffill', axis = 1)
# Out:
#                                        state confirmed  active   passive  \
# 0                        Andaman and Nicobar     10742     1.0     10612
# 1                             Andhra Pradesh   2339067     3.0   2324331
# 2                          Arunachal Pradesh     66890   66890     66594
# 3                                      Assam    746100     0.0    738065
# 4                                      Bihar    851379    15.0    839062
# 5                                 Chandigarh     99348     6.0     98161
# 6                               Chhattisgarh   1177749     6.0   1163597
# 7   Dadra and Nagar Haveli and Daman and Diu     11591     0.0     11587
# 8                                      Delhi   2007188    35.0   1980632
# 9                                        NaN  259079.0    26.0  255040.0
# 10                                   Gujarat   1277557    41.0   1266473
# 11                                   Haryana   1056602    43.0   1045845
# ...

# %%
df2.replace(to_replace = 'Bihar', value = 'BIHAR')
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742     1.0    10612
# 1                             Andhra Pradesh    2339067     3.0  2324331
# 2                          Arunachal Pradesh      66890     NaN    66594
# 3                                      Assam     746100     0.0   738065
# 4                                      BIHAR     851379    15.0   839062
# 5                                 Chandigarh      99348     6.0    98161
# 6                               Chhattisgarh    1177749     6.0  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591     0.0    11587
# 8                                      Delhi    2007188    35.0  1980632
# 9                                        NaN     259079    26.0   255040
# 10                                   Gujarat    1277557    41.0  1266473
# 11                                   Haryana    1056602    43.0  1045845
# ...

# %%
fd = {
    "name":["soham","vishal","vaibhavi","shrusti"],
    "age" : [23,26,28,22],
    "Address": ["maninagar","ghodasar","ab","surat"]
}

sd = pd.DataFrame(fd)
sd
# Out:
#        name  age    Address
# 0     soham   23  maninagar
# 1    vishal   26   ghodasar
# 2  vaibhavi   28         ab
# 3   shrusti   22      surat

# %%
fd1 = {
    "name":["soham","vishal","vaibhavi","shrusti"],
    "age" : [23,26,28,22],
    "Address": ["maninagar","ghodasar","ab","surat"]
}

sd1 = pd.DataFrame(fd1)
sd1
# Out:
#        name  age    Address
# 0     soham   23  maninagar
# 1    vishal   26   ghodasar
# 2  vaibhavi   28         ab
# 3   shrusti   22      surat

# %%
fdd2 = concatnate(fd1, sd1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14300\3318130512.py in <module>
# ----> 1 fdd2 = concatnate(fd1, sd1)
#
# NameError: name 'concatnate' is not defined
