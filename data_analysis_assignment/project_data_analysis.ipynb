# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
audi = pd.read_csv('D:\\vishal data\\csv file\\audi.csv')
audi
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0   NaN
# 2        A1  2016.0  11000.0       Manual      NaN   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0   NaN
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol    NaN  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3     NaN  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi.isnull().sum().sum()
# Out:
# 27

# %%
audi.isnull().any()
# Out:
# model           False
# year             True
# price            True
# transmission     True
# mileage          True
# fuelType         True
# tax              True
# mpg              True
# engineSize       True
# dtype: bool

# %%
audi.isnull().sum().sum()
# Out:
# 27

# %%
audi.fillna(15)
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0  15.0
# 2        A1  2016.0  11000.0       Manual     15.0   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0  15.0
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol   15.0  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3    15.0  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi.dropna()
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 5        A1  2016.0  13900.0    Automatic  32260.0   Petrol   30.0  58.9
# 6        A6  2016.0  13250.0    Automatic  76788.0   Diesel   30.0  61.4
# 8        A3  2015.0  10200.0       Manual  46112.0   Petrol   20.0  60.1
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10661    A4  2011.0   6995.0       Manual  95000.0   Diesel  145.0  53.3
# 10662    A3  2013.0  12695.0       Manual  31500.0   Petrol  125.0  53.3
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 3             2.0
# 5             1.4
# ...

# %%
audi.fillna(method='ffill')
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0  55.4
# 2        A1  2016.0  11000.0       Manual  36203.0   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0  67.3
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol  150.0  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3  2017.0  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi.interpolate()
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0  55.4
# 2        A1  2016.0  11000.0       Manual  31077.5   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0  63.1
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol  150.0  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3  2017.0  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi[['fuelType','price']].groupby('fuelType').sum()
# Out:
#                 price
# fuelType
# Diesel    129552684.0
# Hybrid       845369.0
# Petrol    113738650.0

# %%
audi[['fuelType','price']].groupby('fuelType').mean()
# Out:
#                  price
# fuelType
# Diesel    23242.318622
# Hybrid    30191.750000
# Petrol    22486.882167

# %%
audi.fillna(method = 'bfill')
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0  55.4
# 2        A1  2016.0  11000.0       Manual  25952.0   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0  58.9
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol  150.0  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3     NaN  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi
# Out:
#       model    year    price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017.0  12500.0       Manual  15735.0   Petrol  150.0  55.4
# 1        A6  2016.0  16500.0    Automatic  36203.0   Diesel   20.0   NaN
# 2        A1  2016.0  11000.0       Manual      NaN   Petrol   30.0  55.4
# 3        A4  2017.0  16800.0    Automatic  25952.0   Diesel  145.0  67.3
# 4        A3  2019.0  17300.0       Manual   1998.0   Petrol  145.0   NaN
# ...     ...     ...      ...          ...      ...      ...    ...   ...
# 10663    A3  2020.0  16999.0       Manual   4018.0   Petrol  145.0  49.6
# 10664    A3  2020.0  16999.0       Manual   1978.0   Petrol  150.0  49.6
# 10665    A3  2020.0  17199.0       Manual    609.0   Petrol    NaN  49.6
# 10666    Q3  2017.0  19499.0    Automatic   8646.0   Petrol  150.0  47.9
# 10667    Q3     NaN  15999.0       Manual  11855.0   Petrol  150.0  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# ...

# %%
audi[['model', 'transmission', 'price']].head()
# Out:
#   model transmission    price
# 0    A1       Manual  12500.0
# 1    A6    Automatic  16500.0
# 2    A1       Manual  11000.0
# 3    A4    Automatic  16800.0
# 4    A3       Manual  17300.0

# %%
audi.sort_values(by=['price'], ascending = False).head()
# Out:
#      model    year     price transmission  mileage fuelType    tax   mpg  \
# 4783    R8  2020.0  145000.0    Semi-Auto   2000.0   Petrol  145.0  21.1
# 2255    R8  2020.0  137995.0    Semi-Auto     70.0   Petrol  145.0  21.1
# 4179    R8  2019.0  137500.0    Semi-Auto     10.0   Petrol  150.0  21.4
# 3367    R8  2019.0  135000.0    Automatic   1000.0   Petrol  145.0  32.8
# 5459    R8  2020.0  133900.0    Semi-Auto    333.0   Petrol  145.0  21.4
#
#       engineSize
# 4783         5.2
# 2255         5.2
# 4179         5.2
# 3367         5.2
# 5459         5.2

# %%
audi.sort_values(by = ['price'], na_position = 'first').head()
# Out:
#       model    year   price transmission   mileage fuelType    tax   mpg  \
# 3700     A4  2017.0     NaN       Manual   31000.0   Diesel  145.0  70.6
# 8903     A3  2015.0     NaN       Manual   21872.0   Petrol  125.0  53.3
# 10379    A4  2019.0     NaN    Automatic    6992.0   Petrol  145.0  38.7
# 10588    A3  2003.0  1490.0    Automatic  101000.0   Diesel  240.0  44.5
# 10552    A4  2004.0  1699.0       Manual  110000.0   Diesel  315.0  36.2
#
#        engineSize
# 3700          2.0
# 8903          1.4
# 10379         2.0
# 10588         1.9
# 10552         2.5

# %%
audi['price'].min()
# Out:
# 1490.0

# %%
audi['price'].max()
# Out:
# 145000.0

# %%
audi['price'].median()
# Out:
# 20200.0

# %%
audi['price'].mean()
# Out:
# 22898.3484294421

# %%
audi['price'].mode()
# Out:
# 0    19995.0
# Name: price, dtype: float64

# %%
audi['model'].count()
# Out:
# 10668

# %%
plt.plot(audi['model'], audi['price'], 'o')
plt.show()
