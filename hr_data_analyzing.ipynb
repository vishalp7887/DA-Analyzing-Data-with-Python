# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\vishal data\\csv file\\HR Data.csv')

# %%
df
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df1 = df.iloc[1]

# %%
df1.to_dict()
# Out:
# {'Attrition': 'No',
#  'Business Travel': 'Travel_Frequently',
#  'CF_age band': '45 - 54',
#  'CF_attrition label': 'Current Employees',
#  'Department': 'R&D',
#  'Education Field': 'Life Sciences',
#  'emp no': 'STAFF-2',
#  'Employee Number': 2,
#  'Gender': 'Male',
#  'Job Role': 'Research Scientist',
#  'Marital Status': 'Married',
#  'Over Time': 'No',
#  'Over18': 'Y',
#  'Training Times Last Year': 3,
#  'Age': 49,
#  'CF_current Employee': 1,
#  'Daily Rate': 279,
#  'Distance From Home': 8,
#  'Education': 'High School',
#  'Employee Count': 1,
#  'Environment Satisfaction': 3,
#  'Hourly Rate': 61,
#  'Job Involvement': 2,
#  'Job Level': 2,
#  'Job Satisfaction': 2,
#  'Monthly Income': 5130,
#  'Monthly Rate': 24907,
#  'Num Companies Worked': 1,
#  'Percent Salary Hike': 23,
#  'Performance Rating': 4,
#  'Relationship Satisfaction': 4,
#  'Standard Hours': 80,
#  'Stock Option Level': 1,
#  'Total Working Years': 10,
#  'Work Life Balance': 3,
# ...

# %%
new = df['Education Field'].str.split(' ', n=9, expand = True)

# %%
new
# Out:
#               0         1
# 0          Life  Sciences
# 1          Life  Sciences
# 2         Other      None
# 3          Life  Sciences
# 4       Medical      None
# ...         ...       ...
# 1465  Technical    Degree
# 1466       Life  Sciences
# 1467      Other      None
# 1468       Life  Sciences
# 1469       Life  Sciences
#
# [1470 rows x 2 columns]

# %%
df['Education Field'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.groupby(['CF_age band']).sum()
# Out:
#              Employee Number  Training Times Last Year    Age  \
# CF_age band
# 25 - 34               568877                      1559  16699
# 35 - 44               530298                      1421  19586
# 45 - 54               245451                       675  11963
# Over 55                66454                       181   3924
# Under 25               95472                       279   2106
#
#              CF_current Employee  Daily Rate  Distance From Home  \
# CF_age band
# 25 - 34                      442      441835                5018
# 35 - 44                      454      403948                4733
# 45 - 54                      220      206583                2221
# Over 55                       58       52177                 629
# Under 25                      59       75111                 912
#
#              Employee Count  Environment Satisfaction  Hourly Rate  \
# CF_age band
# 25 - 34                 554                      1508        36190
# ...

# %%
df['Standard Hours'] - df['Total Working Years']
# Out:
# 0       72
# 1       70
# 2       73
# 3       72
# 4       74
#         ..
# 1465    75
# 1466    79
# 1467    67
# 1468    79
# 1469    77
# Length: 1470, dtype: int64

# %%
df['Business Travel'].str.split('_', expand = True)
# Out:
#                0           1
# 0         Travel      Rarely
# 1         Travel  Frequently
# 2         Travel      Rarely
# 3         Travel  Frequently
# 4         Travel      Rarely
# ...          ...         ...
# 1465  Non-Travel        None
# 1466      Travel  Frequently
# 1467      Travel  Frequently
# 1468      Travel      Rarely
# 1469      Travel      Rarely
#
# [1470 rows x 2 columns]

# %%
df3 = df['Business Travel'].str.partition('_')
df3.columns = ['Travel', 'underscore', 'business']
df3.drop(df3[df3['underscore'] != '_'].index, inplace = True)
df3
# Out:
#       Travel underscore    business
# 0     Travel          _      Rarely
# 1     Travel          _  Frequently
# 2     Travel          _      Rarely
# 3     Travel          _  Frequently
# 4     Travel          _      Rarely
# ...      ...        ...         ...
# 1464  Travel          _      Rarely
# 1466  Travel          _  Frequently
# 1467  Travel          _  Frequently
# 1468  Travel          _      Rarely
# 1469  Travel          _      Rarely
#
# [1320 rows x 3 columns]

# %%
df3.to_csv('Hr_travel.csv')
